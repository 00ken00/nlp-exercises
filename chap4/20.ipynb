# %% [markdown]
# ◑ Write a function that takes a list of words (containing duplicates) and returns a list of words (with no duplicates) sorted by decreasing frequency. E.g. if the input list contained 10 instances of the word table and 9 instances of the word chair, then table would appear before chair in the output list.

# %%
def sorted_frequency(words):
    word_dict = {}
    for word in words:
        if not word in word_dict:
            word_dict[word] = 1
        else:
            word_dict[word] += 1

    return [item[0] for item in sorted(word_dict.items(), lambda x,y: cmp(y[1], x[1]))]

# %%
import nltk

words = nltk.corpus.abc.words('science.txt')[:500]
sorted_frequency(words)
# Out:
# [u'the',
#  u'of',
#  u',',
#  u'a',
#  u'and',
#  u'.',
#  u'salt',
#  u'in',
#  u'to',
#  u'"',
#  u'that',
#  u'water',
#  u'mist',
#  u'fibrosis',
#  u'inhaled',
#  u'US',
#  u'cystic',
#  u'with',
#  u'patients',
#  u'it',
#  u'children',
#  u'treatment',
#  u'found',
#  u'says',
#  u'7',
#  u'by',
#  u'30',
#  u'studies',
#  u'or',
#  u'lung',
#  u'adults',
#  u'have',
#  u'%',
#  u'The',
#  u'for',
#  u'Ratjen',
#  u'less',
#  u'produced',
#  u'first',
#  u'which',
#  u'Weinmann',
#  u'effects',
#  u'one',
#  u'school',
#  u'solution',
#  u'team',
#  u'side',
#  u'work',
#  u'Hospital',
#  u"'",
#  u'That',
#  u'affects',
#  u'content',
#  u'may',
#  u'new',
#  u'alone',
#  u'improved',
#  u's',
#  u'absenteeism',
#  u'published',
#  u'young',
#  u'from',
#  u'would',
#  u'mucus',
#  u'function',
#  u'lungs',
#  u'coughing',
#  u'infection',
#  u'than',
#  u'Cystic',
#  u'colleagues',
#  u'can',
#  u'study',
#  u'Elkins',
#  u'taste',
#  u'is',
#  u'as',
#  u'-',
#  u'Dr',
#  u'who',
#  u'000',
#  u'In',
#  u'Canada',
#  u'%.',
#  u'just',
#  u'both',
#  u'debris',
#  u'including',
#  u'Hill',
#  u'avenue',
#  u'chemical',
#  u'based',
#  u'system',
#  u'fit',
#  u'immune',
#  u'had',
#  u'Inhaling',
#  u'unpleasant',
#  u'under',
#  u'fatal',
#  u'regularly',
#  u'them',
#  u'breathing',
#  u'possible',
#  u'they',
#  u'not',
#  u'nasty',
#  u'treating',
#  u'Heart',
#  u'several',
#  u'England',
#  u'progressive',
#  u'accompanying',
#  u'Felix',
#  u'fewer',
#  u'try',
#  u'bad',
#  u'systemic',
#  u'Chapel',
#  u'approaching',
#  u'Adding',
#  u'beneficial',
#  u'Sick',
#  u'people',
#  u',"',
#  u'reduce',
#  u'Mark',
#  u'second',
#  u'Alfred',
#  u'New',
#  u'rescued',
#  u'bacteria',
#  u'best',
#  u'really',
#  u'surfaces',
#  u'appear',
#  u'overwhelmed',
#  u'issue',
#  u'He',
#  u'limitations',
#  u'be',
#  u'airways',
#  u'University',
#  u'drug',
#  u'step',
#  u'Australia',
#  u'term',
#  u'although',
#  u'airway',
#  u'North',
#  u'[',
#  u'pus',
#  u'inhaling',
#  u'about',
#  u'getting',
#  u'National',
#  u'Prince',
#  u'passages',
#  u'mean',
#  u'Donaldson',
#  u'authored',
#  u'Children',
#  u'conclude',
#  u'Royal',
#  u'marked',
#  u'administer',
#  u'because',
#  u'been',
#  u'sufferers',
#  u'Scientists',
#  u'Medicine',
#  u'antibiotic',
#  u'open',
#  u'hydrate',
#  u'thickening',
#  u'their',
#  u'Assistant',
#  u'two',
#  u'long',
#  u'genetic',
#  u'much',
#  u'treat',
#  u'Profsesor',
#  u'was',
#  u'cited',
#  u'opens',
#  u'more',
#  u'some',
#  u'sustained',
#  u'cases',
#  u'those',
#  u'include',
#  u'this',
#  u'mists',
#  u'harder',
#  u'up',
#  u'will',
#  u'Lung',
#  u'editorial',
#  u'were',
#  u'minutes',
#  u'Toronto',
#  u'better',
#  u'83',
#  u'received',
#  u'an',
#  u'helped',
#  u'his',
#  u'salty',
#  u'at',
#  u'take',
#  u'mouse',
#  u'if',
#  u'acceleration',
#  u'lengthy',
#  u'harsh',
#  u'Journal',
#  u'1',
#  u'how',
#  u'Blood',
#  u'They',
#  u'Gail',
#  u'9',
#  u'Carolina',
#  u'Sydney',
#  u'conclusion',
#  u'week',
#  u'added',
#  u'inherent',
#  u'Institute',
#  u'problems',
#  u'sponsored',
#  u'blood',
#  u'fits',
#  u'frequently',
#  u'But',
#  u']',
#  u'All',
#  u'clearance',
#  u'effective',
#  u'fills',
#  u'makes',
#  u'clear',
#  u'disease',
#  u'Scott',
#  u'volunteers',
#  u'make']
